# %%
import csv
import random
import os
from datetime import datetime

# 🔧 Cấu hình
MAX_OUTPUT_ROWS = 1000000  # Tổng số dòng muốn sinh ra
PASSENGER_FILE = "level_1/Passenger.csv"
BOOKING_FILE = "level_3/Booking.csv"
OUTPUT_FILE = "level_4/BookingPassenger.csv"

# 📥 Load dữ liệu Booking & Passenger
with open(BOOKING_FILE, newline='') as f:
    bookings = list(csv.DictReader(f))

with open(PASSENGER_FILE, newline='') as f:
    passengers = list(csv.DictReader(f))

# 📦 Sinh dữ liệu BookingPassenger
booking_passenger_records = []
total_generated = 0

for booking in bookings:
    if total_generated >= MAX_OUTPUT_ROWS:
        break

    booking_id = booking["BookingID"]
    num_passengers = random.randint(1, 5)

    selected_passengers = random.sample(passengers, num_passengers)
    primary_contact = random.choice(selected_passengers)["PassengerID"]

    for passenger in selected_passengers:
        booking_passenger_records.append({
            "BookingID": booking_id,
            "PassengerID": passenger["PassengerID"],
            "IsPrimaryContact": "TRUE" if passenger["PassengerID"] == primary_contact else "FALSE",
            "CreatedAt": int(datetime.utcnow().timestamp())
        })
        total_generated += 1

        if total_generated >= MAX_OUTPUT_ROWS:
            break

# 💾 Ghi file CSV
os.makedirs(os.path.dirname(OUTPUT_FILE), exist_ok=True)
with open(OUTPUT_FILE, mode="w", newline='') as f:
    writer = csv.DictWriter(f, fieldnames=["BookingID", "PassengerID", "IsPrimaryContact", "CreatedAt"])
    writer.writeheader()
    writer.writerows(booking_passenger_records)

print(f"✅ Đã ghi {len(booking_passenger_records)} dòng vào {OUTPUT_FILE}")
# Out:
# C:\Users\huy37\AppData\Local\Temp\ipykernel_10460\378242384.py:38: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "CreatedAt": int(datetime.utcnow().timestamp())
# ✅ Đã ghi 1000000 dòng vào level_4/BookingPassenger.csv

# %%
import csv

input_file = "level_3/OperationalFlightLeg_full.csv"
output_file = "level_3/LegID_OperatingAirlineID.csv"

# Mở file input và output
with open(input_file, newline='', encoding='utf-8') as infile, \
     open(output_file, mode='w', newline='', encoding='utf-8') as outfile:
    
    reader = csv.DictReader(infile)
    writer = csv.DictWriter(outfile, fieldnames=['LegID', 'OperatingAirlineID'])
    
    writer.writeheader()
    for row in reader:
        writer.writerow({
            'LegID': row['LegID'],
            'OperatingAirlineID': row['OperatingAirlineID']
        })

print(f"✅ Đã tạo file mới: {output_file}")
# Out:
# ✅ Đã tạo file mới: level_3/LegID_OperatingAirlineID.csv

# %%
import csv

input_file = "level_2/crewMem.csv"
output_file = "level_2/short_crewMem.csv"

# Mở file input và output
with open(input_file, newline='', encoding='utf-8') as infile, \
     open(output_file, mode='w', newline='', encoding='utf-8') as outfile:
    
    reader = csv.DictReader(infile)
    writer = csv.DictWriter(outfile, fieldnames=['CrewMemberID', 'Role', 'AirlineID'])
    
    writer.writeheader()
    for row in reader:
        writer.writerow({
            'CrewMemberID': row['CrewMemberID'],
            'Role': row['Role'],
            'AirlineID': row['AirlineID']
        })

print(f"✅ Đã tạo file mới: {output_file}")
# Out:
# ✅ Đã tạo file mới: level_2/short_crewMem.csv

# %%
import csv
import random
import os
from datetime import datetime

# ==== CẤU HÌNH ====
MAX_OUTPUT_ROWS = 1000000
CHUNK_SIZE = 500
OUTPUT_DIR = "level_4/split_FlightCrewAssignment"

# ==== ĐỌC DỮ LIỆU ====
def read_csv_to_dictlist(path):
    with open(path, newline='', encoding='utf-8') as f:
        return list(csv.DictReader(f))

legs = read_csv_to_dictlist("level_3/LegID_OperatingAirlineID.csv")
crew = read_csv_to_dictlist("level_2/short_crewMem.csv")

# ==== TÁCH PHI HÀNH ĐOÀN THEO ROLE ====
crew_by_role = {'Captain': [], 'First Officer': [], 'Purser': [], 'Flight Attendant': []}
for member in crew:
    role = member['Role']
    if role in crew_by_role:
        crew_by_role[role].append(member)

# ==== GÁN PHI HÀNH ĐOÀN ====
assignments = []
roles = ['Captain', 'First Officer', 'Purser', 'Flight Attendant']

for leg in legs:
    if len(assignments) >= MAX_OUTPUT_ROWS:
        break

    leg_id = leg['LegID']
    airline_id = leg['OperatingAirlineID']
    used_crew_ids = set()
    leg_assignments = []

    # Gán ít nhất 1 phi công
    pilot_roles = ['Captain', 'First Officer']
    pilot_assigned = False
    for role in pilot_roles:
        available = [c for c in crew_by_role[role] if c['AirlineID'] == airline_id and c['CrewMemberID'] not in used_crew_ids]
        if available:
            selected = random.choice(available)
            crew_id = selected['CrewMemberID']
            used_crew_ids.add(crew_id)
            leg_assignments.append({
                'OperationalFlightLegID': leg_id,
                'CrewMemberID': crew_id,
                'AssignedRole': role,
                'CreatedAt': int(datetime.utcnow().timestamp())
            })
            pilot_assigned = True
            break  # Chỉ cần 1 phi công là đủ

    if pilot_assigned:
        # Có thể gán thêm thành viên khác nếu muốn (ví dụ tiếp viên)
        for role in ['Purser', 'Flight Attendant']:
            available = [c for c in crew_by_role[role] if c['AirlineID'] == airline_id and c['CrewMemberID'] not in used_crew_ids]
            if available:
                selected = random.choice(available)
                crew_id = selected['CrewMemberID']
                used_crew_ids.add(crew_id)
                leg_assignments.append({
                    'OperationalFlightLegID': leg_id,
                    'CrewMemberID': crew_id,
                    'AssignedRole': role,
                    'CreatedAt': int(datetime.utcnow().timestamp())
                })

        assignments.extend(leg_assignments)

# ==== GHI FILE CSV THEO TỪNG KHỐI 500 DÒNG ====
os.makedirs(OUTPUT_DIR, exist_ok=True)

total_written = 0

for i in range(0, len(assignments), CHUNK_SIZE):
    chunk = assignments[i:i+CHUNK_SIZE]
    filename = os.path.join(OUTPUT_DIR, f"FlightCrewAssignment_{str(i // CHUNK_SIZE + 1).zfill(3)}.csv")
    
    with open(filename, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['OperationalFlightLegID', 'CrewMemberID', 'AssignedRole', 'CreatedAt'])
        writer.writeheader()
        writer.writerows(chunk)

    total_written += len(chunk)
    print(f"✅ Ghi {len(chunk)} dòng vào {filename} — 📦 Tổng cộng đã sinh: {total_written} dòng")
# Out:
# C:\Users\huy37\AppData\Local\Temp\ipykernel_6340\469601366.py:52: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   'CreatedAt': int(datetime.utcnow().timestamp())
# C:\Users\huy37\AppData\Local\Temp\ipykernel_6340\469601366.py:69: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   'CreatedAt': int(datetime.utcnow().timestamp())
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_001.csv — 📦 Tổng cộng đã sinh: 500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_002.csv — 📦 Tổng cộng đã sinh: 1000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_003.csv — 📦 Tổng cộng đã sinh: 1500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_004.csv — 📦 Tổng cộng đã sinh: 2000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_005.csv — 📦 Tổng cộng đã sinh: 2500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_006.csv — 📦 Tổng cộng đã sinh: 3000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_007.csv — 📦 Tổng cộng đã sinh: 3500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_008.csv — 📦 Tổng cộng đã sinh: 4000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_009.csv — 📦 Tổng cộng đã sinh: 4500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_010.csv — 📦 Tổng cộng đã sinh: 5000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_011.csv — 📦 Tổng cộng đã sinh: 5500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_012.csv — 📦 Tổng cộng đã sinh: 6000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_013.csv — 📦 Tổng cộng đã sinh: 6500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_014.csv — 📦 Tổng cộng đã sinh: 7000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_015.csv — 📦 Tổng cộng đã sinh: 7500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_016.csv — 📦 Tổng cộng đã sinh: 8000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_017.csv — 📦 Tổng cộng đã sinh: 8500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_018.csv — 📦 Tổng cộng đã sinh: 9000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_019.csv — 📦 Tổng cộng đã sinh: 9500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_020.csv — 📦 Tổng cộng đã sinh: 10000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_021.csv — 📦 Tổng cộng đã sinh: 10500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_022.csv — 📦 Tổng cộng đã sinh: 11000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_023.csv — 📦 Tổng cộng đã sinh: 11500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_024.csv — 📦 Tổng cộng đã sinh: 12000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_025.csv — 📦 Tổng cộng đã sinh: 12500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_026.csv — 📦 Tổng cộng đã sinh: 13000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_027.csv — 📦 Tổng cộng đã sinh: 13500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_028.csv — 📦 Tổng cộng đã sinh: 14000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_029.csv — 📦 Tổng cộng đã sinh: 14500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_030.csv — 📦 Tổng cộng đã sinh: 15000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_031.csv — 📦 Tổng cộng đã sinh: 15500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_032.csv — 📦 Tổng cộng đã sinh: 16000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_033.csv — 📦 Tổng cộng đã sinh: 16500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_034.csv — 📦 Tổng cộng đã sinh: 17000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_035.csv — 📦 Tổng cộng đã sinh: 17500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_036.csv — 📦 Tổng cộng đã sinh: 18000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_037.csv — 📦 Tổng cộng đã sinh: 18500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_038.csv — 📦 Tổng cộng đã sinh: 19000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_039.csv — 📦 Tổng cộng đã sinh: 19500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_040.csv — 📦 Tổng cộng đã sinh: 20000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_041.csv — 📦 Tổng cộng đã sinh: 20500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_042.csv — 📦 Tổng cộng đã sinh: 21000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_043.csv — 📦 Tổng cộng đã sinh: 21500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_044.csv — 📦 Tổng cộng đã sinh: 22000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_045.csv — 📦 Tổng cộng đã sinh: 22500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_046.csv — 📦 Tổng cộng đã sinh: 23000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_047.csv — 📦 Tổng cộng đã sinh: 23500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_048.csv — 📦 Tổng cộng đã sinh: 24000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_049.csv — 📦 Tổng cộng đã sinh: 24500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_050.csv — 📦 Tổng cộng đã sinh: 25000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_051.csv — 📦 Tổng cộng đã sinh: 25500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_052.csv — 📦 Tổng cộng đã sinh: 26000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_053.csv — 📦 Tổng cộng đã sinh: 26500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_054.csv — 📦 Tổng cộng đã sinh: 27000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_055.csv — 📦 Tổng cộng đã sinh: 27500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_056.csv — 📦 Tổng cộng đã sinh: 28000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_057.csv — 📦 Tổng cộng đã sinh: 28500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_058.csv — 📦 Tổng cộng đã sinh: 29000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_059.csv — 📦 Tổng cộng đã sinh: 29500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_060.csv — 📦 Tổng cộng đã sinh: 30000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_061.csv — 📦 Tổng cộng đã sinh: 30500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_062.csv — 📦 Tổng cộng đã sinh: 31000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_063.csv — 📦 Tổng cộng đã sinh: 31500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_064.csv — 📦 Tổng cộng đã sinh: 32000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_065.csv — 📦 Tổng cộng đã sinh: 32500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_066.csv — 📦 Tổng cộng đã sinh: 33000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_067.csv — 📦 Tổng cộng đã sinh: 33500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_068.csv — 📦 Tổng cộng đã sinh: 34000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_069.csv — 📦 Tổng cộng đã sinh: 34500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_070.csv — 📦 Tổng cộng đã sinh: 35000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_071.csv — 📦 Tổng cộng đã sinh: 35500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_072.csv — 📦 Tổng cộng đã sinh: 36000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_073.csv — 📦 Tổng cộng đã sinh: 36500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_074.csv — 📦 Tổng cộng đã sinh: 37000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_075.csv — 📦 Tổng cộng đã sinh: 37500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_076.csv — 📦 Tổng cộng đã sinh: 38000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_077.csv — 📦 Tổng cộng đã sinh: 38500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_078.csv — 📦 Tổng cộng đã sinh: 39000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_079.csv — 📦 Tổng cộng đã sinh: 39500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_080.csv — 📦 Tổng cộng đã sinh: 40000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_081.csv — 📦 Tổng cộng đã sinh: 40500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_082.csv — 📦 Tổng cộng đã sinh: 41000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_083.csv — 📦 Tổng cộng đã sinh: 41500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_084.csv — 📦 Tổng cộng đã sinh: 42000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_085.csv — 📦 Tổng cộng đã sinh: 42500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_086.csv — 📦 Tổng cộng đã sinh: 43000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_087.csv — 📦 Tổng cộng đã sinh: 43500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_088.csv — 📦 Tổng cộng đã sinh: 44000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_089.csv — 📦 Tổng cộng đã sinh: 44500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_090.csv — 📦 Tổng cộng đã sinh: 45000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_091.csv — 📦 Tổng cộng đã sinh: 45500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_092.csv — 📦 Tổng cộng đã sinh: 46000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_093.csv — 📦 Tổng cộng đã sinh: 46500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_094.csv — 📦 Tổng cộng đã sinh: 47000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_095.csv — 📦 Tổng cộng đã sinh: 47500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_096.csv — 📦 Tổng cộng đã sinh: 48000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_097.csv — 📦 Tổng cộng đã sinh: 48500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_098.csv — 📦 Tổng cộng đã sinh: 49000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_099.csv — 📦 Tổng cộng đã sinh: 49500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_100.csv — 📦 Tổng cộng đã sinh: 50000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_101.csv — 📦 Tổng cộng đã sinh: 50500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_102.csv — 📦 Tổng cộng đã sinh: 51000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_103.csv — 📦 Tổng cộng đã sinh: 51500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_104.csv — 📦 Tổng cộng đã sinh: 52000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_105.csv — 📦 Tổng cộng đã sinh: 52500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_106.csv — 📦 Tổng cộng đã sinh: 53000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_107.csv — 📦 Tổng cộng đã sinh: 53500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_108.csv — 📦 Tổng cộng đã sinh: 54000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_109.csv — 📦 Tổng cộng đã sinh: 54500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_110.csv — 📦 Tổng cộng đã sinh: 55000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_111.csv — 📦 Tổng cộng đã sinh: 55500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_112.csv — 📦 Tổng cộng đã sinh: 56000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_113.csv — 📦 Tổng cộng đã sinh: 56500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_114.csv — 📦 Tổng cộng đã sinh: 57000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_115.csv — 📦 Tổng cộng đã sinh: 57500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_116.csv — 📦 Tổng cộng đã sinh: 58000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_117.csv — 📦 Tổng cộng đã sinh: 58500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_118.csv — 📦 Tổng cộng đã sinh: 59000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_119.csv — 📦 Tổng cộng đã sinh: 59500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_120.csv — 📦 Tổng cộng đã sinh: 60000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_121.csv — 📦 Tổng cộng đã sinh: 60500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_122.csv — 📦 Tổng cộng đã sinh: 61000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_123.csv — 📦 Tổng cộng đã sinh: 61500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_124.csv — 📦 Tổng cộng đã sinh: 62000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_125.csv — 📦 Tổng cộng đã sinh: 62500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_126.csv — 📦 Tổng cộng đã sinh: 63000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_127.csv — 📦 Tổng cộng đã sinh: 63500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_128.csv — 📦 Tổng cộng đã sinh: 64000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_129.csv — 📦 Tổng cộng đã sinh: 64500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_130.csv — 📦 Tổng cộng đã sinh: 65000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_131.csv — 📦 Tổng cộng đã sinh: 65500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_132.csv — 📦 Tổng cộng đã sinh: 66000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_133.csv — 📦 Tổng cộng đã sinh: 66500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_134.csv — 📦 Tổng cộng đã sinh: 67000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_135.csv — 📦 Tổng cộng đã sinh: 67500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_136.csv — 📦 Tổng cộng đã sinh: 68000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_137.csv — 📦 Tổng cộng đã sinh: 68500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_138.csv — 📦 Tổng cộng đã sinh: 69000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_139.csv — 📦 Tổng cộng đã sinh: 69500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_140.csv — 📦 Tổng cộng đã sinh: 70000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_141.csv — 📦 Tổng cộng đã sinh: 70500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_142.csv — 📦 Tổng cộng đã sinh: 71000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_143.csv — 📦 Tổng cộng đã sinh: 71500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_144.csv — 📦 Tổng cộng đã sinh: 72000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_145.csv — 📦 Tổng cộng đã sinh: 72500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_146.csv — 📦 Tổng cộng đã sinh: 73000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_147.csv — 📦 Tổng cộng đã sinh: 73500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_148.csv — 📦 Tổng cộng đã sinh: 74000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_149.csv — 📦 Tổng cộng đã sinh: 74500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_150.csv — 📦 Tổng cộng đã sinh: 75000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_151.csv — 📦 Tổng cộng đã sinh: 75500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_152.csv — 📦 Tổng cộng đã sinh: 76000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_153.csv — 📦 Tổng cộng đã sinh: 76500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_154.csv — 📦 Tổng cộng đã sinh: 77000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_155.csv — 📦 Tổng cộng đã sinh: 77500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_156.csv — 📦 Tổng cộng đã sinh: 78000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_157.csv — 📦 Tổng cộng đã sinh: 78500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_158.csv — 📦 Tổng cộng đã sinh: 79000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_159.csv — 📦 Tổng cộng đã sinh: 79500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_160.csv — 📦 Tổng cộng đã sinh: 80000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_161.csv — 📦 Tổng cộng đã sinh: 80500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_162.csv — 📦 Tổng cộng đã sinh: 81000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_163.csv — 📦 Tổng cộng đã sinh: 81500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_164.csv — 📦 Tổng cộng đã sinh: 82000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_165.csv — 📦 Tổng cộng đã sinh: 82500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_166.csv — 📦 Tổng cộng đã sinh: 83000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_167.csv — 📦 Tổng cộng đã sinh: 83500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_168.csv — 📦 Tổng cộng đã sinh: 84000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_169.csv — 📦 Tổng cộng đã sinh: 84500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_170.csv — 📦 Tổng cộng đã sinh: 85000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_171.csv — 📦 Tổng cộng đã sinh: 85500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_172.csv — 📦 Tổng cộng đã sinh: 86000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_173.csv — 📦 Tổng cộng đã sinh: 86500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_174.csv — 📦 Tổng cộng đã sinh: 87000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_175.csv — 📦 Tổng cộng đã sinh: 87500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_176.csv — 📦 Tổng cộng đã sinh: 88000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_177.csv — 📦 Tổng cộng đã sinh: 88500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_178.csv — 📦 Tổng cộng đã sinh: 89000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_179.csv — 📦 Tổng cộng đã sinh: 89500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_180.csv — 📦 Tổng cộng đã sinh: 90000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_181.csv — 📦 Tổng cộng đã sinh: 90500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_182.csv — 📦 Tổng cộng đã sinh: 91000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_183.csv — 📦 Tổng cộng đã sinh: 91500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_184.csv — 📦 Tổng cộng đã sinh: 92000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_185.csv — 📦 Tổng cộng đã sinh: 92500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_186.csv — 📦 Tổng cộng đã sinh: 93000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_187.csv — 📦 Tổng cộng đã sinh: 93500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_188.csv — 📦 Tổng cộng đã sinh: 94000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_189.csv — 📦 Tổng cộng đã sinh: 94500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_190.csv — 📦 Tổng cộng đã sinh: 95000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_191.csv — 📦 Tổng cộng đã sinh: 95500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_192.csv — 📦 Tổng cộng đã sinh: 96000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_193.csv — 📦 Tổng cộng đã sinh: 96500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_194.csv — 📦 Tổng cộng đã sinh: 97000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_195.csv — 📦 Tổng cộng đã sinh: 97500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_196.csv — 📦 Tổng cộng đã sinh: 98000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_197.csv — 📦 Tổng cộng đã sinh: 98500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_198.csv — 📦 Tổng cộng đã sinh: 99000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_199.csv — 📦 Tổng cộng đã sinh: 99500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_200.csv — 📦 Tổng cộng đã sinh: 100000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_201.csv — 📦 Tổng cộng đã sinh: 100500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_202.csv — 📦 Tổng cộng đã sinh: 101000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_203.csv — 📦 Tổng cộng đã sinh: 101500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_204.csv — 📦 Tổng cộng đã sinh: 102000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_205.csv — 📦 Tổng cộng đã sinh: 102500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_206.csv — 📦 Tổng cộng đã sinh: 103000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_207.csv — 📦 Tổng cộng đã sinh: 103500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_208.csv — 📦 Tổng cộng đã sinh: 104000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_209.csv — 📦 Tổng cộng đã sinh: 104500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_210.csv — 📦 Tổng cộng đã sinh: 105000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_211.csv — 📦 Tổng cộng đã sinh: 105500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_212.csv — 📦 Tổng cộng đã sinh: 106000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_213.csv — 📦 Tổng cộng đã sinh: 106500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_214.csv — 📦 Tổng cộng đã sinh: 107000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_215.csv — 📦 Tổng cộng đã sinh: 107500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_216.csv — 📦 Tổng cộng đã sinh: 108000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_217.csv — 📦 Tổng cộng đã sinh: 108500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_218.csv — 📦 Tổng cộng đã sinh: 109000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_219.csv — 📦 Tổng cộng đã sinh: 109500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_220.csv — 📦 Tổng cộng đã sinh: 110000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_221.csv — 📦 Tổng cộng đã sinh: 110500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_222.csv — 📦 Tổng cộng đã sinh: 111000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_223.csv — 📦 Tổng cộng đã sinh: 111500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_224.csv — 📦 Tổng cộng đã sinh: 112000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_225.csv — 📦 Tổng cộng đã sinh: 112500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_226.csv — 📦 Tổng cộng đã sinh: 113000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_227.csv — 📦 Tổng cộng đã sinh: 113500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_228.csv — 📦 Tổng cộng đã sinh: 114000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_229.csv — 📦 Tổng cộng đã sinh: 114500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_230.csv — 📦 Tổng cộng đã sinh: 115000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_231.csv — 📦 Tổng cộng đã sinh: 115500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_232.csv — 📦 Tổng cộng đã sinh: 116000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_233.csv — 📦 Tổng cộng đã sinh: 116500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_234.csv — 📦 Tổng cộng đã sinh: 117000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_235.csv — 📦 Tổng cộng đã sinh: 117500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_236.csv — 📦 Tổng cộng đã sinh: 118000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_237.csv — 📦 Tổng cộng đã sinh: 118500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_238.csv — 📦 Tổng cộng đã sinh: 119000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_239.csv — 📦 Tổng cộng đã sinh: 119500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_240.csv — 📦 Tổng cộng đã sinh: 120000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_241.csv — 📦 Tổng cộng đã sinh: 120500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_242.csv — 📦 Tổng cộng đã sinh: 121000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_243.csv — 📦 Tổng cộng đã sinh: 121500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_244.csv — 📦 Tổng cộng đã sinh: 122000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_245.csv — 📦 Tổng cộng đã sinh: 122500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_246.csv — 📦 Tổng cộng đã sinh: 123000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_247.csv — 📦 Tổng cộng đã sinh: 123500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_248.csv — 📦 Tổng cộng đã sinh: 124000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_249.csv — 📦 Tổng cộng đã sinh: 124500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_250.csv — 📦 Tổng cộng đã sinh: 125000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_251.csv — 📦 Tổng cộng đã sinh: 125500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_252.csv — 📦 Tổng cộng đã sinh: 126000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_253.csv — 📦 Tổng cộng đã sinh: 126500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_254.csv — 📦 Tổng cộng đã sinh: 127000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_255.csv — 📦 Tổng cộng đã sinh: 127500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_256.csv — 📦 Tổng cộng đã sinh: 128000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_257.csv — 📦 Tổng cộng đã sinh: 128500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_258.csv — 📦 Tổng cộng đã sinh: 129000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_259.csv — 📦 Tổng cộng đã sinh: 129500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_260.csv — 📦 Tổng cộng đã sinh: 130000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_261.csv — 📦 Tổng cộng đã sinh: 130500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_262.csv — 📦 Tổng cộng đã sinh: 131000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_263.csv — 📦 Tổng cộng đã sinh: 131500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_264.csv — 📦 Tổng cộng đã sinh: 132000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_265.csv — 📦 Tổng cộng đã sinh: 132500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_266.csv — 📦 Tổng cộng đã sinh: 133000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_267.csv — 📦 Tổng cộng đã sinh: 133500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_268.csv — 📦 Tổng cộng đã sinh: 134000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_269.csv — 📦 Tổng cộng đã sinh: 134500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_270.csv — 📦 Tổng cộng đã sinh: 135000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_271.csv — 📦 Tổng cộng đã sinh: 135500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_272.csv — 📦 Tổng cộng đã sinh: 136000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_273.csv — 📦 Tổng cộng đã sinh: 136500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_274.csv — 📦 Tổng cộng đã sinh: 137000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_275.csv — 📦 Tổng cộng đã sinh: 137500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_276.csv — 📦 Tổng cộng đã sinh: 138000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_277.csv — 📦 Tổng cộng đã sinh: 138500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_278.csv — 📦 Tổng cộng đã sinh: 139000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_279.csv — 📦 Tổng cộng đã sinh: 139500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_280.csv — 📦 Tổng cộng đã sinh: 140000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_281.csv — 📦 Tổng cộng đã sinh: 140500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_282.csv — 📦 Tổng cộng đã sinh: 141000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_283.csv — 📦 Tổng cộng đã sinh: 141500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_284.csv — 📦 Tổng cộng đã sinh: 142000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_285.csv — 📦 Tổng cộng đã sinh: 142500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_286.csv — 📦 Tổng cộng đã sinh: 143000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_287.csv — 📦 Tổng cộng đã sinh: 143500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_288.csv — 📦 Tổng cộng đã sinh: 144000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_289.csv — 📦 Tổng cộng đã sinh: 144500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_290.csv — 📦 Tổng cộng đã sinh: 145000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_291.csv — 📦 Tổng cộng đã sinh: 145500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_292.csv — 📦 Tổng cộng đã sinh: 146000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_293.csv — 📦 Tổng cộng đã sinh: 146500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_294.csv — 📦 Tổng cộng đã sinh: 147000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_295.csv — 📦 Tổng cộng đã sinh: 147500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_296.csv — 📦 Tổng cộng đã sinh: 148000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_297.csv — 📦 Tổng cộng đã sinh: 148500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_298.csv — 📦 Tổng cộng đã sinh: 149000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_299.csv — 📦 Tổng cộng đã sinh: 149500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_300.csv — 📦 Tổng cộng đã sinh: 150000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_301.csv — 📦 Tổng cộng đã sinh: 150500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_302.csv — 📦 Tổng cộng đã sinh: 151000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_303.csv — 📦 Tổng cộng đã sinh: 151500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_304.csv — 📦 Tổng cộng đã sinh: 152000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_305.csv — 📦 Tổng cộng đã sinh: 152500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_306.csv — 📦 Tổng cộng đã sinh: 153000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_307.csv — 📦 Tổng cộng đã sinh: 153500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_308.csv — 📦 Tổng cộng đã sinh: 154000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_309.csv — 📦 Tổng cộng đã sinh: 154500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_310.csv — 📦 Tổng cộng đã sinh: 155000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_311.csv — 📦 Tổng cộng đã sinh: 155500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_312.csv — 📦 Tổng cộng đã sinh: 156000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_313.csv — 📦 Tổng cộng đã sinh: 156500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_314.csv — 📦 Tổng cộng đã sinh: 157000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_315.csv — 📦 Tổng cộng đã sinh: 157500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_316.csv — 📦 Tổng cộng đã sinh: 158000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_317.csv — 📦 Tổng cộng đã sinh: 158500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_318.csv — 📦 Tổng cộng đã sinh: 159000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_319.csv — 📦 Tổng cộng đã sinh: 159500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_320.csv — 📦 Tổng cộng đã sinh: 160000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_321.csv — 📦 Tổng cộng đã sinh: 160500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_322.csv — 📦 Tổng cộng đã sinh: 161000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_323.csv — 📦 Tổng cộng đã sinh: 161500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_324.csv — 📦 Tổng cộng đã sinh: 162000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_325.csv — 📦 Tổng cộng đã sinh: 162500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_326.csv — 📦 Tổng cộng đã sinh: 163000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_327.csv — 📦 Tổng cộng đã sinh: 163500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_328.csv — 📦 Tổng cộng đã sinh: 164000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_329.csv — 📦 Tổng cộng đã sinh: 164500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_330.csv — 📦 Tổng cộng đã sinh: 165000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_331.csv — 📦 Tổng cộng đã sinh: 165500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_332.csv — 📦 Tổng cộng đã sinh: 166000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_333.csv — 📦 Tổng cộng đã sinh: 166500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_334.csv — 📦 Tổng cộng đã sinh: 167000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_335.csv — 📦 Tổng cộng đã sinh: 167500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_336.csv — 📦 Tổng cộng đã sinh: 168000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_337.csv — 📦 Tổng cộng đã sinh: 168500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_338.csv — 📦 Tổng cộng đã sinh: 169000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_339.csv — 📦 Tổng cộng đã sinh: 169500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_340.csv — 📦 Tổng cộng đã sinh: 170000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_341.csv — 📦 Tổng cộng đã sinh: 170500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_342.csv — 📦 Tổng cộng đã sinh: 171000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_343.csv — 📦 Tổng cộng đã sinh: 171500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_344.csv — 📦 Tổng cộng đã sinh: 172000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_345.csv — 📦 Tổng cộng đã sinh: 172500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_346.csv — 📦 Tổng cộng đã sinh: 173000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_347.csv — 📦 Tổng cộng đã sinh: 173500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_348.csv — 📦 Tổng cộng đã sinh: 174000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_349.csv — 📦 Tổng cộng đã sinh: 174500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_350.csv — 📦 Tổng cộng đã sinh: 175000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_351.csv — 📦 Tổng cộng đã sinh: 175500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_352.csv — 📦 Tổng cộng đã sinh: 176000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_353.csv — 📦 Tổng cộng đã sinh: 176500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_354.csv — 📦 Tổng cộng đã sinh: 177000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_355.csv — 📦 Tổng cộng đã sinh: 177500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_356.csv — 📦 Tổng cộng đã sinh: 178000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_357.csv — 📦 Tổng cộng đã sinh: 178500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_358.csv — 📦 Tổng cộng đã sinh: 179000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_359.csv — 📦 Tổng cộng đã sinh: 179500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_360.csv — 📦 Tổng cộng đã sinh: 180000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_361.csv — 📦 Tổng cộng đã sinh: 180500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_362.csv — 📦 Tổng cộng đã sinh: 181000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_363.csv — 📦 Tổng cộng đã sinh: 181500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_364.csv — 📦 Tổng cộng đã sinh: 182000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_365.csv — 📦 Tổng cộng đã sinh: 182500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_366.csv — 📦 Tổng cộng đã sinh: 183000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_367.csv — 📦 Tổng cộng đã sinh: 183500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_368.csv — 📦 Tổng cộng đã sinh: 184000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_369.csv — 📦 Tổng cộng đã sinh: 184500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_370.csv — 📦 Tổng cộng đã sinh: 185000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_371.csv — 📦 Tổng cộng đã sinh: 185500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_372.csv — 📦 Tổng cộng đã sinh: 186000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_373.csv — 📦 Tổng cộng đã sinh: 186500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_374.csv — 📦 Tổng cộng đã sinh: 187000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_375.csv — 📦 Tổng cộng đã sinh: 187500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_376.csv — 📦 Tổng cộng đã sinh: 188000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_377.csv — 📦 Tổng cộng đã sinh: 188500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_378.csv — 📦 Tổng cộng đã sinh: 189000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_379.csv — 📦 Tổng cộng đã sinh: 189500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_380.csv — 📦 Tổng cộng đã sinh: 190000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_381.csv — 📦 Tổng cộng đã sinh: 190500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_382.csv — 📦 Tổng cộng đã sinh: 191000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_383.csv — 📦 Tổng cộng đã sinh: 191500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_384.csv — 📦 Tổng cộng đã sinh: 192000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_385.csv — 📦 Tổng cộng đã sinh: 192500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_386.csv — 📦 Tổng cộng đã sinh: 193000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_387.csv — 📦 Tổng cộng đã sinh: 193500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_388.csv — 📦 Tổng cộng đã sinh: 194000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_389.csv — 📦 Tổng cộng đã sinh: 194500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_390.csv — 📦 Tổng cộng đã sinh: 195000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_391.csv — 📦 Tổng cộng đã sinh: 195500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_392.csv — 📦 Tổng cộng đã sinh: 196000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_393.csv — 📦 Tổng cộng đã sinh: 196500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_394.csv — 📦 Tổng cộng đã sinh: 197000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_395.csv — 📦 Tổng cộng đã sinh: 197500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_396.csv — 📦 Tổng cộng đã sinh: 198000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_397.csv — 📦 Tổng cộng đã sinh: 198500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_398.csv — 📦 Tổng cộng đã sinh: 199000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_399.csv — 📦 Tổng cộng đã sinh: 199500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_400.csv — 📦 Tổng cộng đã sinh: 200000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_401.csv — 📦 Tổng cộng đã sinh: 200500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_402.csv — 📦 Tổng cộng đã sinh: 201000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_403.csv — 📦 Tổng cộng đã sinh: 201500 dòng
# ...
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1868.csv — 📦 Tổng cộng đã sinh: 934000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1869.csv — 📦 Tổng cộng đã sinh: 934500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1870.csv — 📦 Tổng cộng đã sinh: 935000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1871.csv — 📦 Tổng cộng đã sinh: 935500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1872.csv — 📦 Tổng cộng đã sinh: 936000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1873.csv — 📦 Tổng cộng đã sinh: 936500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1874.csv — 📦 Tổng cộng đã sinh: 937000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1875.csv — 📦 Tổng cộng đã sinh: 937500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1876.csv — 📦 Tổng cộng đã sinh: 938000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1877.csv — 📦 Tổng cộng đã sinh: 938500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1878.csv — 📦 Tổng cộng đã sinh: 939000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1879.csv — 📦 Tổng cộng đã sinh: 939500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1880.csv — 📦 Tổng cộng đã sinh: 940000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1881.csv — 📦 Tổng cộng đã sinh: 940500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1882.csv — 📦 Tổng cộng đã sinh: 941000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1883.csv — 📦 Tổng cộng đã sinh: 941500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1884.csv — 📦 Tổng cộng đã sinh: 942000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1885.csv — 📦 Tổng cộng đã sinh: 942500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1886.csv — 📦 Tổng cộng đã sinh: 943000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1887.csv — 📦 Tổng cộng đã sinh: 943500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1888.csv — 📦 Tổng cộng đã sinh: 944000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1889.csv — 📦 Tổng cộng đã sinh: 944500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1890.csv — 📦 Tổng cộng đã sinh: 945000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1891.csv — 📦 Tổng cộng đã sinh: 945500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1892.csv — 📦 Tổng cộng đã sinh: 946000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1893.csv — 📦 Tổng cộng đã sinh: 946500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1894.csv — 📦 Tổng cộng đã sinh: 947000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1895.csv — 📦 Tổng cộng đã sinh: 947500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1896.csv — 📦 Tổng cộng đã sinh: 948000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1897.csv — 📦 Tổng cộng đã sinh: 948500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1898.csv — 📦 Tổng cộng đã sinh: 949000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1899.csv — 📦 Tổng cộng đã sinh: 949500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1900.csv — 📦 Tổng cộng đã sinh: 950000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1901.csv — 📦 Tổng cộng đã sinh: 950500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1902.csv — 📦 Tổng cộng đã sinh: 951000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1903.csv — 📦 Tổng cộng đã sinh: 951500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1904.csv — 📦 Tổng cộng đã sinh: 952000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1905.csv — 📦 Tổng cộng đã sinh: 952500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1906.csv — 📦 Tổng cộng đã sinh: 953000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1907.csv — 📦 Tổng cộng đã sinh: 953500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1908.csv — 📦 Tổng cộng đã sinh: 954000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1909.csv — 📦 Tổng cộng đã sinh: 954500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1910.csv — 📦 Tổng cộng đã sinh: 955000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1911.csv — 📦 Tổng cộng đã sinh: 955500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1912.csv — 📦 Tổng cộng đã sinh: 956000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1913.csv — 📦 Tổng cộng đã sinh: 956500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1914.csv — 📦 Tổng cộng đã sinh: 957000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1915.csv — 📦 Tổng cộng đã sinh: 957500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1916.csv — 📦 Tổng cộng đã sinh: 958000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1917.csv — 📦 Tổng cộng đã sinh: 958500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1918.csv — 📦 Tổng cộng đã sinh: 959000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1919.csv — 📦 Tổng cộng đã sinh: 959500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1920.csv — 📦 Tổng cộng đã sinh: 960000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1921.csv — 📦 Tổng cộng đã sinh: 960500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1922.csv — 📦 Tổng cộng đã sinh: 961000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1923.csv — 📦 Tổng cộng đã sinh: 961500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1924.csv — 📦 Tổng cộng đã sinh: 962000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1925.csv — 📦 Tổng cộng đã sinh: 962500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1926.csv — 📦 Tổng cộng đã sinh: 963000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1927.csv — 📦 Tổng cộng đã sinh: 963500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1928.csv — 📦 Tổng cộng đã sinh: 964000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1929.csv — 📦 Tổng cộng đã sinh: 964500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1930.csv — 📦 Tổng cộng đã sinh: 965000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1931.csv — 📦 Tổng cộng đã sinh: 965500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1932.csv — 📦 Tổng cộng đã sinh: 966000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1933.csv — 📦 Tổng cộng đã sinh: 966500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1934.csv — 📦 Tổng cộng đã sinh: 967000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1935.csv — 📦 Tổng cộng đã sinh: 967500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1936.csv — 📦 Tổng cộng đã sinh: 968000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1937.csv — 📦 Tổng cộng đã sinh: 968500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1938.csv — 📦 Tổng cộng đã sinh: 969000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1939.csv — 📦 Tổng cộng đã sinh: 969500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1940.csv — 📦 Tổng cộng đã sinh: 970000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1941.csv — 📦 Tổng cộng đã sinh: 970500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1942.csv — 📦 Tổng cộng đã sinh: 971000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1943.csv — 📦 Tổng cộng đã sinh: 971500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1944.csv — 📦 Tổng cộng đã sinh: 972000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1945.csv — 📦 Tổng cộng đã sinh: 972500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1946.csv — 📦 Tổng cộng đã sinh: 973000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1947.csv — 📦 Tổng cộng đã sinh: 973500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1948.csv — 📦 Tổng cộng đã sinh: 974000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1949.csv — 📦 Tổng cộng đã sinh: 974500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1950.csv — 📦 Tổng cộng đã sinh: 975000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1951.csv — 📦 Tổng cộng đã sinh: 975500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1952.csv — 📦 Tổng cộng đã sinh: 976000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1953.csv — 📦 Tổng cộng đã sinh: 976500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1954.csv — 📦 Tổng cộng đã sinh: 977000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1955.csv — 📦 Tổng cộng đã sinh: 977500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1956.csv — 📦 Tổng cộng đã sinh: 978000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1957.csv — 📦 Tổng cộng đã sinh: 978500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1958.csv — 📦 Tổng cộng đã sinh: 979000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1959.csv — 📦 Tổng cộng đã sinh: 979500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1960.csv — 📦 Tổng cộng đã sinh: 980000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1961.csv — 📦 Tổng cộng đã sinh: 980500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1962.csv — 📦 Tổng cộng đã sinh: 981000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1963.csv — 📦 Tổng cộng đã sinh: 981500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1964.csv — 📦 Tổng cộng đã sinh: 982000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1965.csv — 📦 Tổng cộng đã sinh: 982500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1966.csv — 📦 Tổng cộng đã sinh: 983000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1967.csv — 📦 Tổng cộng đã sinh: 983500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1968.csv — 📦 Tổng cộng đã sinh: 984000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1969.csv — 📦 Tổng cộng đã sinh: 984500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1970.csv — 📦 Tổng cộng đã sinh: 985000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1971.csv — 📦 Tổng cộng đã sinh: 985500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1972.csv — 📦 Tổng cộng đã sinh: 986000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1973.csv — 📦 Tổng cộng đã sinh: 986500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1974.csv — 📦 Tổng cộng đã sinh: 987000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1975.csv — 📦 Tổng cộng đã sinh: 987500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1976.csv — 📦 Tổng cộng đã sinh: 988000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1977.csv — 📦 Tổng cộng đã sinh: 988500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1978.csv — 📦 Tổng cộng đã sinh: 989000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1979.csv — 📦 Tổng cộng đã sinh: 989500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1980.csv — 📦 Tổng cộng đã sinh: 990000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1981.csv — 📦 Tổng cộng đã sinh: 990500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1982.csv — 📦 Tổng cộng đã sinh: 991000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1983.csv — 📦 Tổng cộng đã sinh: 991500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1984.csv — 📦 Tổng cộng đã sinh: 992000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1985.csv — 📦 Tổng cộng đã sinh: 992500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1986.csv — 📦 Tổng cộng đã sinh: 993000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1987.csv — 📦 Tổng cộng đã sinh: 993500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1988.csv — 📦 Tổng cộng đã sinh: 994000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1989.csv — 📦 Tổng cộng đã sinh: 994500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1990.csv — 📦 Tổng cộng đã sinh: 995000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1991.csv — 📦 Tổng cộng đã sinh: 995500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1992.csv — 📦 Tổng cộng đã sinh: 996000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1993.csv — 📦 Tổng cộng đã sinh: 996500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1994.csv — 📦 Tổng cộng đã sinh: 997000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1995.csv — 📦 Tổng cộng đã sinh: 997500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1996.csv — 📦 Tổng cộng đã sinh: 998000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1997.csv — 📦 Tổng cộng đã sinh: 998500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1998.csv — 📦 Tổng cộng đã sinh: 999000 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_1999.csv — 📦 Tổng cộng đã sinh: 999500 dòng
# ✅ Ghi 500 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_2000.csv — 📦 Tổng cộng đã sinh: 1000000 dòng
# ✅ Ghi 2 dòng vào level_4/split_FlightCrewAssignment\FlightCrewAssignment_2001.csv — 📦 Tổng cộng đã sinh: 1000002 dòng
